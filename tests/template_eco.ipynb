# %%
import warnings
warnings.filterwarnings('ignore')
import pyfesom2 as pf
import py_f2recom as pyf
import numpy as np
import os
import sys
from datetime import date
import cmocean as cmo

mesh = pf.load_mesh(pyf.datasets.meshpath)
# Out:
# osgeo is not installed, conversion to Geo formats like Geotiff (fesom2GeoFormat) will not work.
#
# ==> Processing years from 2000 to 2023
#
# Reading out of /albedo/scratch/user/simuel001/phd/output_JRA/b_varClim_1958_2024/
# Storing graphs to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/
# Storing html to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/ as A__2026_07_23_ocean_ice.html
#
# ==> You can configure the post-processing parameters & paths in : py_f2recom/src/datasets.py
#
# /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2

# %%
pyf.plot_maps_limfact(mesh, first_year = pyf.datasets.first_year_maps)
# Out:
# Version with diatoms, small phytoplankton, coccolithophores, and polar Phaeocystis
# yearly frequency selected

# %%
pyf.plot_seasonalcycle_bio(mesh, first_year = pyf.datasets.first_year_maps)

# %%
pyf.plot_seasonalcycle_bio(mesh, first_year = pyf.datasets.first_year_maps, type = 'NPP')

# %%
pyf.plot_maps_all_pfts(mesh)
# Out:
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0
# Upper depth: 0.0, Lower depth: -6000.0

# %%
pyf.plot_maps_npp_global(mesh)
# Out:
#  !!! Satellite data for the 1998-2019 period only !!!
# 4-phytoplankton model is used
#  NPP SAT Southern Ocean [PgC / yr] =  3.482732855576151
#  NPP REcoM Southern Ocean [PgC / yr] =  2.801233071487705
#  NPP SAT Global [PgC / yr] =  50.49647800498724
#  NPP REcoM Global [PgC / yr] =  40.807342172020014
# WARNING: OCNPP field contains NaNs
#
# Statistics for log10 surface NPP
#
# Original Taylor stats:
# SDEV pred: 0.32803, ref: 0.27332
# CRMS pred: 0.38935, ref: 0.00000
# CORRCOEF: 0.17128
#
# Normalized Taylor stats:
# SDEV pred: 1.20017, ref: 1.00000
# CRMS pred: 1.42453, ref: 0.00000
# CORRCOEF: 0.17128
# Adjust axis max to 1.5

# %%
pyf.plot_maps_npp_global(mesh, matfileNPPsurf=pyf.datasets.matfileNPPcpbm)
# Out:
#  !!! Satellite data for the 1998-2019 period only !!!
# 4-phytoplankton model is used
#  NPP SAT Southern Ocean [PgC / yr] =  3.9206203734774023
#  NPP REcoM Southern Ocean [PgC / yr] =  2.801233071487705
#  NPP SAT Global [PgC / yr] =  68.93480650824961
#  NPP REcoM Global [PgC / yr] =  40.807342172020014
# WARNING: OCNPP field contains NaNs
#
# Statistics for log10 surface NPP
#
# Original Taylor stats:
# SDEV pred: 0.29090, ref: 0.24674
# CRMS pred: 0.34217, ref: 0.00000
# CORRCOEF: 0.19800
#
# Normalized Taylor stats:
# SDEV pred: 1.17899, ref: 1.00000
# CRMS pred: 1.38677, ref: 0.00000
# CORRCOEF: 0.19800
# Adjust axis max to 1.5

# %%
pyf.plot_maps_npp_arctic(mesh)
# Out:
# Lewis et al. dataset selected
#  !!! Only MODIS Satellite for the 2003-2018 period !!!
# 4-phytoplankton model is used
# WARNING: Satellite field contains NaNs
#
# Statistics for log10 NPP
#
# Original Taylor stats:
# SDEV pred: 0.49854, ref: 0.67061
# CRMS pred: 0.42643, ref: 0.00000
# CORRCOEF: 0.77233
#
# Normalized Taylor stats:
# SDEV pred: 0.74342, ref: 1.00000
# CRMS pred: 0.63588, ref: 0.00000
# CORRCOEF: 0.77233

# %%
pyf.plot_maps_npp_arctic(mesh, npfile=pyf.datasets.npfileNPParcCMEMS)
# Out:
# Globcolour dataset selected
#  !!! Only MODIS Satellite for the 2003-2018 period !!!
# 4-phytoplankton model is used
# WARNING: Satellite field contains NaNs
#
# Statistics for log10 NPP
#
# Original Taylor stats:
# SDEV pred: 0.44129, ref: 0.49455
# CRMS pred: 0.33554, ref: 0.00000
# CORRCOEF: 0.74855
#
# Normalized Taylor stats:
# SDEV pred: 0.89231, ref: 1.00000
# CRMS pred: 0.67849, ref: 0.00000
# CORRCOEF: 0.74855

# %%
pyf.plot_maps_chl_arctic(mesh)
# Out:
# Lewis et al. dataset selected
#  !!! Only MODIS Satellite for the 2003-2021 period !!!
# 4-phytoplankton model is used
# WARNING: Satellite field contains NaNs
#
# Statistics for log10 surface Chlorophyll
#
# Original Taylor stats:
# SDEV pred: 0.16896, ref: 0.38336
# CRMS pred: 0.34845, ref: 0.00000
# CORRCOEF: 0.41759
#
# Normalized Taylor stats:
# SDEV pred: 0.44073, ref: 1.00000
# CRMS pred: 0.90893, ref: 0.00000
# CORRCOEF: 0.41759

# %%
pyf.plot_maps_chl_arctic(mesh, ncfile=pyf.datasets.ncfileChlArcOCCCI)
# Out:
# OCCCI. dataset selected
#  !!! Only Satellite data for the 2000-2019 period !!!
# 4-phytoplankton model is used
# WARNING: Satellite field contains NaNs
#
# Statistics for log10 surface Chlorophyll
#
# Original Taylor stats:
# SDEV pred: 0.17678, ref: 0.39715
# CRMS pred: 0.38870, ref: 0.00000
# CORRCOEF: 0.26985
#
# Normalized Taylor stats:
# SDEV pred: 0.44513, ref: 1.00000
# CRMS pred: 0.97873, ref: 0.00000
# CORRCOEF: 0.26985

# %%
pyf.plot_maps_chl_global(mesh)
# Out:
#  !!! Satellite data only for 2012-2015 period !!!
# 4-phytoplankton model is used
# WARNING: OCCCI field contains NaNs
#
# Statistics for log10 surface Chlorophyll
#
# Original Taylor stats:
# SDEV pred: 0.26535, ref: 0.44571
# CRMS pred: 0.42395, ref: 0.00000
# CORRCOEF: 0.37765
#
# Normalized Taylor stats:
# SDEV pred: 0.59533, ref: 1.00000
# CRMS pred: 0.95119, ref: 0.00000
# CORRCOEF: 0.37765

# %%
pyf.plot_maps_chl_southern(mesh)
# Out:
# 4-phytoplankton model is used
# WARNING: Johnson field contains NaNs
#
# Statistics for log10 surface Chlorophyll
#
# Original Taylor stats:
# SDEV pred: 0.22998, ref: 0.33909
# CRMS pred: 0.35338, ref: 0.00000
# CORRCOEF: 0.27655
#
# Normalized Taylor stats:
# SDEV pred: 0.67823, ref: 1.00000
# CRMS pred: 1.04216, ref: 0.00000
# CORRCOEF: 0.27655
