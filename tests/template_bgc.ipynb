# %%
import warnings
warnings.filterwarnings('ignore')
import pyfesom2 as pf
import py_f2recom as pyf
import numpy as np
import os
import sys
from datetime import date
import cmocean as cmo

mesh = pf.load_mesh(pyf.datasets.meshpath)
# Out:
# osgeo is not installed, conversion to Geo formats like Geotiff (fesom2GeoFormat) will not work.
#
# ==> Processing years from 1805 to 1805
#
# Reading out of /albedo/work/user/silech001/
# Storing graphs to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/
# Storing html to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/ as A__2026_04_27_ocean_ice.html
#
# ==> You can configure the post-processing parameters & paths in : py_f2recom/src/datasets.py
#
# /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2

# %%
pyf.plot_maps_din(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_n00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 5.6655, std = 9.2350, min = 0.0035, max = 35.1670
# WOA mean = 9.9098, std = 8.7276, min = 0.0166, max = 33.1955
# Original Taylor stats:
# SDEV pred: 9.23496, ref: 8.72757
# CRMS pred: 4.73828, ref: 0.00000
# CORRCOEF: 0.86232
#
# Normalized Taylor stats:
# SDEV pred: 1.05814, ref: 1.00000
# CRMS pred: 0.54291, ref: 0.00000
# CORRCOEF: 0.86232
# Adjust axis max to 1.5

# %%
pyf.plot_maps_dsi(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_i00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
# Original Taylor stats:
# SDEV pred: 18.25911, ref: 18.71464
# CRMS pred: 8.77562, ref: 0.00000
# CORRCOEF: 0.88762
#
# Normalized Taylor stats:
# SDEV pred: 0.97566, ref: 1.00000
# CRMS pred: 0.46892, ref: 0.00000
# CORRCOEF: 0.88762

# %%
pyf.plot_maps_do2(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_all_o00_01_mmol_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 245.4185, std = 68.3529, min = 27.5281, max = 346.9713
# WOA mean = 254.0262, std = 80.1841, min = 42.5206, max = 384.1179
# Original Taylor stats:
# SDEV pred: 68.35290, ref: 80.18412
# CRMS pred: 26.47127, ref: 0.00000
# CORRCOEF: 0.94884
#
# Normalized Taylor stats:
# SDEV pred: 0.85245, ref: 1.00000
# CRMS pred: 0.33013, ref: 0.00000
# CORRCOEF: 0.94884

# %%
pyf.plot_maps_dfe(mesh)
# Out:
# ***
# Depth greater in FESOM (-6125.0) than in PISCES (-5500.0)
# 100m is too deep for climatology.
# Please consider choosing max depth at -2.5!
# ***
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 0.4861, std = 0.7511, min = 0.0007, max = 13.9037
# PISCES mean = 0.4411, std = 0.3686, min = 0.0049, max = 2.9243
# Original Taylor stats:
# SDEV pred: 0.75113, ref: 0.36855
# CRMS pred: 0.73787, ref: 0.00000
# CORRCOEF: 0.28100
#
# Normalized Taylor stats:
# SDEV pred: 2.03805, ref: 1.00000
# CRMS pred: 2.00207, ref: 0.00000
# CORRCOEF: 0.28100
# Adjust axis max to 2.5

# %%
pyf.plot_profiles_nut(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_n00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_i00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# ***
# Depth greater in FESOM (-6125.0) than in PISCES (-5500.0)

# %%
pyf.plot_profiles_do2(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_all_o00_01_mmol_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
