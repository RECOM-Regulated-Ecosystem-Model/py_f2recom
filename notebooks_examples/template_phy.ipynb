# %%
import warnings
warnings.filterwarnings('ignore')
import pyfesom2 as pf
import py_f2recom as pyf
import numpy as np
import os
import sys
from datetime import date
import cmocean as cmo

mesh = pf.load_mesh(pyf.datasets.meshpath)
# Out:
# osgeo is not installed, conversion to Geo formats like Geotiff (fesom2GeoFormat) will not work.
#
# ==> Processing years from 1805 to 1805
#
# Reading out of /albedo/work/user/silech001/
# Storing graphs to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/
# Storing html to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/ as A__2026_04_27_ocean_ice.html
#
# ==> You can configure the post-processing parameters & paths in : py_f2recom/src/datasets.py
#
# /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2

# %%
pyf.plot_mesh_area(mesh)

# %%
pyf.plot_mesh_resolution(mesh)

# %%
pyf.plot_maps_woa_sal(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_decav_s00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 31.6376, std = 7.5905, min = 1.2193, max = 40.3409
# WOA mean = 31.4391, std = 7.5796, min = 1.5163, max = 40.2282
# Original Taylor stats:
# SDEV pred: 7.59054, ref: 7.57963
# CRMS pred: 0.35992, ref: 0.00000
# CORRCOEF: 0.99888
#
# Normalized Taylor stats:
# SDEV pred: 1.00144, ref: 1.00000
# CRMS pred: 0.04749, ref: 0.00000
# CORRCOEF: 0.99888
# Adjust axis max to 1.5

# %%
pyf.plot_maps_woa_temp(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_decav_t00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 9.8381, std = 10.4358, min = -1.8588, max = 29.1603
# WOA mean = 10.2542, std = 10.8018, min = -1.8620, max = 29.1537
# Original Taylor stats:
# SDEV pred: 10.43583, ref: 10.80176
# CRMS pred: 2.42658, ref: 0.00000
# CORRCOEF: 0.97448
#
# Normalized Taylor stats:
# SDEV pred: 0.96612, ref: 1.00000
# CRMS pred: 0.22465, ref: 0.00000
# CORRCOEF: 0.97448

# %%
pyf.plot_maps_phc_sal(mesh)
# Out:
# ***
# Loading PHC file: /albedo/work/projects/p_pool_recom/eval/phc3.0_annual.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in PHC (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 31.6376, std = 7.5905, min = 1.2193, max = 40.3409
# PHC mean = 31.4652, std = 7.5409, min = 1.0779, max = 40.0972
# Original Taylor stats:
# SDEV pred: 7.59054, ref: 7.54088
# CRMS pred: 0.32256, ref: 0.00000
# CORRCOEF: 0.99911
#
# Normalized Taylor stats:
# SDEV pred: 1.00659, ref: 1.00000
# CRMS pred: 0.04278, ref: 0.00000
# CORRCOEF: 0.99911
# Adjust axis max to 1.5

# %%
pyf.plot_maps_phc_sal_regulargrid(mesh)
# Out:
# the model depth is:  100 ; the closest depth in climatology is:  100.0

# %%
pyf.plot_maps_phc_temp_regulargrid(mesh)
# Out:
# the model depth is:  100 ; the closest depth in climatology is:  100.0

# %%
pyf.plot_maps_mld(mesh)
# Out:
# ***
# Loading MLD file: /albedo/work/projects/p_pool_recom/eval/GlobalML_Climato_1970_2018.mat
# ***
# WARNING: The interpolated field contains NaNs

# %%
pyf.plot_profiles_ts(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_decav_s00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_decav_t00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)

# %%
pyf.plot_timeseries_seaice(mesh, first_year= 1979)
# Out:
# ## Observations only for the 1979-2019 period ##

# %%
pyf.plot_timeseries_seaice(mesh, first_year= 1979, region='S')
# Out:
# ## Observations only for the 1979-2019 period ##
