# %%
import warnings
warnings.filterwarnings('ignore')
import pyfesom2 as pf
import py_f2recom as pyf
import numpy as np
import os
import sys
from datetime import date
import cmocean as cmo

mesh = pf.load_mesh(pyf.datasets.meshpath)
# Out:
# ==> Processing years from 2000 to 2023
#
# Reading out of /albedo/scratch/user/simuel001/phd/output_JRA/b_varClim_1958_2024/
# Storing graphs to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/
# Storing html to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/ as A__2026_07_24_ocean_ice.html
#
# ==> You can configure the post-processing parameters & paths in : py_f2recom/src/datasets.py
#
# /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2

# %%
pyf.plot_maps_din(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_n00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 5.1000, std = 8.2440, min = 0.0050, max = 30.5065
# WOA mean = 9.1405, std = 8.8595, min = 0.0024, max = 33.1955
# Original Taylor stats:
# SDEV pred: 8.24402, ref: 8.85947
# CRMS pred: 3.67840, ref: 0.00000
# CORRCOEF: 0.90997
#
# Normalized Taylor stats:
# SDEV pred: 0.93053, ref: 1.00000
# CRMS pred: 0.41519, ref: 0.00000
# CORRCOEF: 0.90997

# %%
pyf.plot_maps_dsi(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_i00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
# Original Taylor stats:
# SDEV pred: 15.80889, ref: 18.71464
# CRMS pred: 8.48548, ref: 0.00000
# CORRCOEF: 0.89258
#
# Normalized Taylor stats:
# SDEV pred: 0.84473, ref: 1.00000
# CRMS pred: 0.45341, ref: 0.00000
# CORRCOEF: 0.89258

# %%
pyf.plot_maps_do2(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_all_o00_01_mmol_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 253.4017, std = 69.0494, min = 52.6057, max = 357.6202
# WOA mean = 254.0262, std = 80.1841, min = 42.5206, max = 384.1179
# Original Taylor stats:
# SDEV pred: 69.04937, ref: 80.18412
# CRMS pred: 24.91554, ref: 0.00000
# CORRCOEF: 0.95514
#
# Normalized Taylor stats:
# SDEV pred: 0.86114, ref: 1.00000
# CRMS pred: 0.31073, ref: 0.00000
# CORRCOEF: 0.95514

# %%
pyf.plot_maps_dfe(mesh)
# Out:
# ***
# Depth greater in FESOM (-6125.0) than in PISCES (-5500.0)
# 100m is too deep for climatology.
# Please consider choosing max depth at -2.5!
# ***
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 0.8698, std = 0.5763, min = 0.0130, max = 4.2128
# PISCES mean = 0.5444, std = 0.5252, min = 0.0108, max = 2.9243
# Original Taylor stats:
# SDEV pred: 0.57633, ref: 0.52517
# CRMS pred: 0.57068, ref: 0.00000
# CORRCOEF: 0.46632
#
# Normalized Taylor stats:
# SDEV pred: 1.09742, ref: 1.00000
# CRMS pred: 1.08666, ref: 0.00000
# CORRCOEF: 0.46632
# Adjust axis max to 1.5

# %%
pyf.plot_profiles_nut(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_n00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa13_all_i00_01_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
# ***
# Depth greater in FESOM (-6125.0) than in PISCES (-5500.0)

# %%
pyf.plot_profiles_do2(mesh)
# Out:
# ***
# Loading WOA file: /albedo/work/projects/p_pool_recom/eval/data/woa18_all_o00_01_mmol_fesom2.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in WOA (-5500.0)
