# %%
import warnings
warnings.filterwarnings('ignore')
import pyfesom2 as pf
import py_f2recom as pyf
import numpy as np
import os
import sys
from datetime import date
import cmocean as cmo

mesh = pf.load_mesh(pyf.datasets.meshpath)
# Out:
# osgeo is not installed, conversion to Geo formats like Geotiff (fesom2GeoFormat) will not work.
#
# ==> Processing years from 2000 to 2023
#
# Reading out of /albedo/scratch/user/simuel001/phd/output_JRA/b_varClim_1958_2024/
# Storing graphs to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/
# Storing html to /albedo/home/loziel/test_py_f2recom_submodules/py_f2recom/outputs/A/ as A__2026_07_27_ocean_ice.html
#
# ==> You can configure the post-processing parameters & paths in : py_f2recom/src/datasets.py
#
# /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /albedo/work/projects/p_bio/mesh/core2/pickle_mesh_py3_fesom2

# %%
import shapely
import cartopy
print("Shapely:", shapely.__version__)
print("Cartopy:", cartopy.__version__)
# Out:
# Shapely: 2.1.2
# Cartopy: 0.25.0

# %%
pyf.plot_maps_dic(mesh)
# Out:
# ***
# Loading GLODAP file: /albedo/work/projects/p_pool_recom/eval/data/GLODAPv2.2016b.TCO2_mmol.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in GLODAP (-5500.0)
# Please consider choosing max depth level 43 with max depth at -5275.0!
# ***
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
# Original Taylor stats:
# SDEV pred: 425.94039, ref: 444.14852
# CRMS pred: 42.52699, ref: 0.00000
# CORRCOEF: 0.99610
#
# Normalized Taylor stats:
# SDEV pred: 0.95900, ref: 1.00000
# CRMS pred: 0.09575, ref: 0.00000
# CORRCOEF: 0.99610

# %%
pyf.plot_maps_alk(mesh)
# Out:
# ***
# Loading GLODAP file: /albedo/work/projects/p_pool_recom/eval/data/GLODAPv2.2016b.TAlk_mmol.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in GLODAP (-5500.0)
# Please consider choosing max depth level 43 with max depth at -5275.0!
# ***
# Upper depth: 0.0, Lower depth: -100.0
# Upper depth: 0.0, Lower depth: -100.0
#
# FESOM mean = 2056.8806, std = 472.5318, min = 488.4760, max = 2728.8959
# PISCES mean = 2158.7214, std = 490.1376, min = 523.1559, max = 2698.4857
# Original Taylor stats:
# SDEV pred: 472.53181, ref: 490.13759
# CRMS pred: 41.00825, ref: 0.00000
# CORRCOEF: 0.99704
#
# Normalized Taylor stats:
# SDEV pred: 0.96408, ref: 1.00000
# CRMS pred: 0.08367, ref: 0.00000
# CORRCOEF: 0.99704

# %%
pco2 = pyf.plot_maps_pco2(mesh, verbose=True, output=True)
# Out:
# ***
# Loading SOCAT file: /albedo/work/projects/p_pool_recom/eval/SOCATv2020_tracks_gridded_monthly.nc
# ***
#
# ***
#  no SOCAT data to be plotted after 2020
# ***
#
# ***
#  years extracted in SOCCAT 2000-2020
# ***
# <function shape at 0x155531077eb0>
#
# Plotting pCO2
# FESOM min = 260.8306491851807, max = 3213.3154927571613
# SOCAT min = 121.06995391845703, max = 1949.374496459961
# (126858,)
# WARNING: The interpolated Glodap field contains NaNs
#
# Original Taylor stats:
# SDEV pred: 43.98491, ref: 48.13514
# CRMS pred: 55.44570, ref: 0.00000
# CORRCOEF: 0.27806
#
# Normalized Taylor stats:
# SDEV pred: 0.91378, ref: 1.00000
# CRMS pred: 1.15188, ref: 0.00000
# CORRCOEF: 0.27806

# %%
pyf.plot_maps_pco2_chau(mesh)
# Out:
# ***
# Loading Chau et al. file: /albedo/work/projects/p_pool_recom/eval/dataset_CO2_Chauetal2020.nc
# ***
#
# ***
#  no Chau et al. data to be plotted after 2020
# ***
#
# ***
#  years extracted in Chau et al. 2000-2020
# ***
# <function shape at 0x155531077e20>
# WARNING: The interpolated Glodap field contains NaNs
# WARNING: The interpolated FESOM field contains NaNs
#
# Original Taylor stats:
# SDEV pred: 2.02502, ref: 1.62871
# CRMS pred: 1.84416, ref: 0.00000
# CORRCOEF: 0.50823
#
# Normalized Taylor stats:
# SDEV pred: 1.24333, ref: 1.00000
# CRMS pred: 1.13228, ref: 0.00000
# CORRCOEF: 0.50823
# Adjust axis max to 1.5

# %%
pyf.plot_profiles_carbs(mesh)
# Out:
# ***
# Loading GLODAP file: /albedo/work/projects/p_pool_recom/eval/data/GLODAPv2.2016b.TCO2_mmol.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in GLODAP (-5500.0)
# Please consider choosing max depth level 43 with max depth at -5275.0!
# ***
# ***
# Loading GLODAP file: /albedo/work/projects/p_pool_recom/eval/data/GLODAPv2.2016b.TAlk_mmol.nc
# ***
# ***
# Depth greater in FESOM (-6125.0) than in GLODAP (-5500.0)
# Please consider choosing max depth level 43 with max depth at -5275.0!
# ***
